# %% [markdown]
# ## 10. Combining Multiple Datasets in the Movie Lens Dataset
#     - Task: Combine and preprocess multiple related datasets from the Movie Lens dataset, such as ratings, user information, and movie metadata.
#     - Dataset: Movie Lens Dataset

# %% [markdown]
# ## Loading and Displaying datasets

# %%
import pandas as pd

# %%
# Load datasets
ratings = pd.read_csv('/kaggle/input/movie-lens-small-latest-dataset/ratings.csv')
tags = pd.read_csv('/kaggle/input/movie-lens-small-latest-dataset/tags.csv')
movies = pd.read_csv('/kaggle/input/movie-lens-small-latest-dataset/movies.csv')
links = pd.read_csv('/kaggle/input/movie-lens-small-latest-dataset/links.csv')

# Display the first few rows of each dataset
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# ## Merge the Datasets

# %%
# Merge ratings with movies
ratings_movies = pd.merge(ratings, movies, on='movieId', how='inner')

# Display the combined dataframe
ratings_movies.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %% [markdown]
# ## Merge the Resulting DataFrame with Tags

# %%
# Merge the resulting dataframe with tags
ratings_movies_tags = pd.merge(ratings_movies, tags, on=['userId', 'movieId'], how='left')

# Display the combined dataframe
ratings_movies_tags.head()
# Out:
#    userId  movieId  rating  timestamp_x                        title  \
# 0       1        1     4.0    964982703             Toy Story (1995)
# 1       1        3     4.0    964981247      Grumpier Old Men (1995)
# 2       1        6     4.0    964982224                  Heat (1995)
# 3       1       47     5.0    964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0    964982931   Usual Suspects, The (1995)
#
#                                         genres  tag  timestamp_y
# 0  Adventure|Animation|Children|Comedy|Fantasy  NaN          NaN
# 1                               Comedy|Romance  NaN          NaN
# 2                        Action|Crime|Thriller  NaN          NaN
# 3                             Mystery|Thriller  NaN          NaN
# 4                       Crime|Mystery|Thriller  NaN          NaN

# %% [markdown]
# ## Merge the Resulting DataFrame with Links

# %%
# Merge the resulting dataframe with links
final_df = pd.merge(ratings_movies_tags, links, on='movieId', how='left')

# Display the combined dataframe
final_df.head()
# Out:
#    userId  movieId  rating  timestamp_x                        title  \
# 0       1        1     4.0    964982703             Toy Story (1995)
# 1       1        3     4.0    964981247      Grumpier Old Men (1995)
# 2       1        6     4.0    964982224                  Heat (1995)
# 3       1       47     5.0    964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0    964982931   Usual Suspects, The (1995)
#
#                                         genres  tag  timestamp_y  imdbId  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  NaN          NaN  114709
# 1                               Comedy|Romance  NaN          NaN  113228
# 2                        Action|Crime|Thriller  NaN          NaN  113277
# 3                             Mystery|Thriller  NaN          NaN  114369
# 4                       Crime|Mystery|Thriller  NaN          NaN  114814
#
#     tmdbId
# 0    862.0
# 1  15602.0
# 2    949.0
# 3    807.0
# 4    629.0

# %% [markdown]
# ## Preprocess the Combined Dataset

# %%
# Check for missing values
print(final_df.isnull().sum())
# Out:
# userId             0
# movieId            0
# rating             0
# timestamp_x        0
# title              0
# genres             0
# tag            99201
# timestamp_y    99201
# imdbId             0
# tmdbId            13
# dtype: int64

# %%
# Drop or fill missing values
final_df = final_df.dropna(subset=['tag'])

# %%
# Check for missing values
print(final_df.isnull().sum())
# Out:
# userId         0
# movieId        0
# rating         0
# timestamp_x    0
# title          0
# genres         0
# tag            0
# timestamp_y    0
# imdbId         0
# tmdbId         0
# dtype: int64

# %% [markdown]
# ## Convert Data type

# %%
# Convert timestamp to datetime
final_df['timestamp_x'] = pd.to_datetime(final_df['timestamp_x'], unit='s')

# Display data types
final_df.dtypes
# Out:
# userId                  int64
# movieId                 int64
# rating                float64
# timestamp_x    datetime64[ns]
# title                  object
# genres                 object
# tag                    object
# timestamp_y           float64
# imdbId                  int64
# tmdbId                float64
# dtype: object

# %% [markdown]
# ## Encode Categorical Variables

# %%
# One-hot encode genres
genres_dummies = final_df['genres'].str.get_dummies(sep='|')
final_df = pd.concat([final_df, genres_dummies], axis=1)

# %%
# Drop the original genres column
final_df = final_df.drop('genres', axis=1)

# %% [markdown]
# ##  Feature Engineering

# %%
# Example: Average rating per user
final_df['user_avg_rating'] = final_df.groupby('userId')['rating'].transform('mean')

# Example: Average rating per movie
final_df['movie_avg_rating'] = final_df.groupby('movieId')['rating'].transform('mean')

# %% [markdown]
# ## Summary and Save the Combined Dataset

# %%
# Save the combined dataset
final_df.to_csv('final_movie_lens_preprocessed.csv', index=False)

# Display the first few rows of the final dataframe
final_df.head()
# Out:
#      userId  movieId  rating         timestamp_x                 title  \
# 241       2    60756     5.0 2015-10-24 19:29:40  Step Brothers (2008)
# 242       2    60756     5.0 2015-10-24 19:29:40  Step Brothers (2008)
# 243       2    60756     5.0 2015-10-24 19:29:40  Step Brothers (2008)
# 252       2    89774     5.0 2015-10-24 19:33:09        Warrior (2011)
# 253       2    89774     5.0 2015-10-24 19:33:09        Warrior (2011)
#
#                  tag   timestamp_y   imdbId   tmdbId  (no genres listed)  ...  \
# 241            funny  1.445715e+09   838283  12133.0                   0  ...
# 242  Highly quotable  1.445715e+09   838283  12133.0                   0  ...
# 243     will ferrell  1.445715e+09   838283  12133.0                   0  ...
# 252     Boxing story  1.445715e+09  1291584  59440.0                   0  ...
# 253              MMA  1.445715e+09  1291584  59440.0                   0  ...
#
#      IMAX  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western  \
# 241     0        0        0        0       0         0    0        0
# 242     0        0        0        0       0         0    0        0
# 243     0        0        0        0       0         0    0        0
# 252     0        0        0        0       0         0    0        0
# 253     0        0        0        0       0         0    0        0
#
#      user_avg_rating  movie_avg_rating
# 241              5.0            4.1875
# 242              5.0            4.1875
# 243              5.0            4.1875
# 252              5.0            5.0000
# 253              5.0            5.0000
#
# [5 rows x 31 columns]
